# %%
import pandas as pd

# %%
pd.read_parquet("../feature_repo/data/driver_stats.parquet")
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 0    2024-07-30 08:00:00+00:00       1005   0.323633  0.241064
# 1    2024-07-30 09:00:00+00:00       1005   0.265231  0.869575
# 2    2024-07-30 10:00:00+00:00       1005   0.734315  0.122275
# 3    2024-07-30 11:00:00+00:00       1005   0.044860  0.108464
# 4    2024-07-30 12:00:00+00:00       1005   0.528886  0.921661
# ...                        ...        ...        ...       ...
# 1802 2024-08-14 06:00:00+00:00       1001   0.061003  0.426603
# 1803 2024-08-14 07:00:00+00:00       1001   0.113299  0.105504
# 1804 2021-04-12 07:00:00+00:00       1001   0.106754  0.121479
# 1805 2024-08-06 20:00:00+00:00       1003   0.006870  0.256827
# 1806 2024-08-06 20:00:00+00:00       1003   0.006870  0.256827
#
#       avg_daily_trips                 created
# 0                 521 2024-08-14 08:57:08.217
# 1                 779 2024-08-14 08:57:08.217
# 2                 374 2024-08-14 08:57:08.217
# ...
